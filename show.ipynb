# %% [markdown]
# # Present first Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import provider as pv
import statistic as st

# %%
major_returns = pv.get_major_forex_returns_from_yahoo()
major_returns.head()
# Out:
# [*********************100%%**********************]  7 of 7 completed
# /home/avatar/Dokumente/Projekte/Python/BasicAnalysis/provider.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data = pdr.get_data_yahoo(majors, start=start, end=end, interval=interval)["Close"].pct_change().dropna()
#               EURUSD    GBPUSD    NZDUSD    USDCAD    USDCHF    USDJPY  \
# Date
# 2006-05-17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2006-05-22  0.001061 -0.002115 -0.009907  0.024339 -0.013927  0.007603
# 2006-05-24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2006-05-29 -0.009231  0.014528  0.013335 -0.007192 -0.001449 -0.015744
# 2006-05-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#               AUDUSD
# Date
# ...

# %%
major_returns.plot.line()
# Out:
# <Axes: xlabel='Date'>

# %%
major_wealth_index = st.wealtch_index(major_returns)
major_wealth_index.plot.line()
# Out:
# <Axes: xlabel='Date'>

# %%
frame = st.show_descriptive_statistics(major_returns)
frame
# Out:
#         Annualized Return  Annualized Volatility  Skewness  Kurtosis  \
# EURUSD              -0.00                   0.09     -0.96     16.99
# GBPUSD              -0.00                   0.07     -0.24      9.81
# NZDUSD              -0.01                   0.07     -1.06     17.37
# USDCAD               0.00                   0.09     -0.31      9.47
# USDCHF               0.00                   0.07      1.35     74.46
# USDJPY              -0.01                   0.07     -1.54     37.53
# AUDUSD               0.01                   0.07      0.18     13.06
#
#         Normal Distribution
# EURUSD                False
# GBPUSD                False
# NZDUSD                False
# USDCAD                False
# USDCHF                False
# USDJPY                False
# AUDUSD                False
