# %% [markdown]
# # Explore Investing.com API

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import provider as pv

# %%
meta = pv.get_currency_pairs_metainformation()

# %%
yield_eur = pv.get_yield_code_basis_currency("EUR", meta)
yield_eur

# %%
yield_usd = pv.get_yield_code_counter_currency("USD", meta)
yield_usd

# %%
eurusd_returns = pv.get_forex_returns_from_investdotcom()
eurusd_returns.head()

# %% [markdown]
# # Explore Yahoo Finance

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import provider as pv

# %%
data = pv.get_test_yield_from_yahoo()
data.plot.line()

# %% [markdown]
# # Explore EconDB.com

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
df = pd.read_csv('https://www.econdb.com/api/series/FRB_H15.4DCCD.M.US/?format=csv&token=29706df6eb6e209a1c20ace67ffd31c6be9f9338', index_col='Date', parse_dates=['Date'])

# %%
df.shape

# %%
import provider as pv

# %%
pv.wrangle_yield_files()

# %%
df = pv.get_yield("EU")

# %%
import numpy as np

# %%
df.plot.line()

# %%
df.loc["2015"]

# %%
basis, counter, diff = pv.get_yield_differential("EURUSD")

# %%
basis.loc["2016"]

# %%
ax = basis.plot()
counter.plot(ax=ax)
diff.plot(ax=ax)
# Out:
# <Axes: xlabel='Date'>

# %%
basis
